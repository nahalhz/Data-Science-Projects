# %% [markdown]
# # Finance Data Project
#
# This data project focuses on exploratory data analysis of stock prices and a way of reenforcing data visualization skills. It is not meant to be a robust financial analysis or be taken as financial advice.The data manipulated is bank stocks and analyzing how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
#  using yahoo finance to directly get those imports in.
#
# ### The Imports

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
yf.pdr_override()
# %matplotlib inline

# %% [markdown]
# ## Getting Data
#
# Gathering stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Getting the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks in seperate dataframes. **
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.

# %%
start = dt.datetime(2006, 1, 1)
end = dt.datetime(2016, 1, 1)
# Bank of America
BAC = data.get_data_yahoo('BAC', start, end)
 
# CitiGroup
C = data.get_data_yahoo('C', start, end)
 
# Goldman Sachs
GS = data.get_data_yahoo('GS', start, end)
 
# JPMorgan Chase
JPM = data.get_data_yahoo('JPM', start, end)
 
# Morgan Stanley
MS = data.get_data_yahoo('MS', start, end)
 
# Wells Fargo
WFC = data.get_data_yahoo('WFC', start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
BAC
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.956562  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  32.606564  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  32.648552  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  32.599567  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  32.620564  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  14.910024  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  14.789153  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  14.918657  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  14.720086  35066400
# 2015-12-31  17.010000  17.070000  16.830000  16.830000  14.530152  47153000
#
# [2517 rows x 6 columns]

# %%
MS
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2006-01-03  57.169998  58.490002  56.740002  58.310001  34.607498  5377000
# 2006-01-04  58.700001  59.279999  58.349998  58.349998  34.631252  7977800
# 2006-01-05  58.549999  58.590000  58.020000  58.509998  34.726204  5778000
# 2006-01-06  58.770000  58.849998  58.049999  58.570000  34.761822  6889800
# 2006-01-09  58.630001  59.290001  58.619999  59.189999  35.129791  4144500
# ...               ...        ...        ...        ...        ...      ...
# 2015-12-24  32.570000  32.709999  32.439999  32.480000  26.863766  2798200
# 2015-12-28  32.360001  32.360001  31.950001  32.169998  26.607372  5420300
# 2015-12-29  32.439999  32.700001  32.330002  32.549999  26.921654  6388200
# 2015-12-30  32.500000  32.650002  32.200001  32.230000  26.656990  5057200
# 2015-12-31  31.910000  32.299999  31.770000  31.809999  26.309614  8154300
#
# [2517 rows x 6 columns]

# %% [markdown]
# ** Created a list of the ticker symbols (as strings) in alphabetical order. **
# ** Then concatenated all dataframes into one big data frame. **

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
bank_stocks = pd.concat([BAC, C , GS, JPM, MS, WFC], axis=1, keys=tickers)

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  32.956562  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  32.606564  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  32.648552  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  32.599567  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  32.620564  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
cross_section = bank_stocks.xs(key='Close', axis=1, level='Stock Info')
newdf1 = None
co 
    newdf.join(newdf1)
    count += 1
newdf1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/59/1yyxp0h910ngl7l951xhh5nm0000gn/T/ipykernel_50893/2092024832.py in <module>
#       9         news2 = cross_section.groupby([tick, (pd.Grouper(freq= '1D'))]).size()
#      10         newdf = news2.to_frame(name=['Date', tick])
# ---> 11     newdf.join(newdf1)
#      12     count += 1
#      13 newdf1.head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'join'

# %% [markdown]
# # Exploring Data
#
# ** max Close price for each bank's stock throughout the time period: **

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# ** Created a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()
tickersR = ['BAC Return', 'C Return', 'GS Return', 'JPM Return', 'MS Return', 'WFC Return']

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
sns.pairplot(returns[1:])

# %% [markdown]
#  ** Using this returns DataFrame, identify what dates each bank stock had the best and worst single day returns. **

# %%
returns.idxmin()         #WORST DAY RETURNS
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** Four banks out of 6 have the worst day returns on the same date of January 20th 2009. January 20, 2009 was the day of Barack Obama's inauguration as the 44th President of the United States. The day was significant for the financial markets as well, as it was in the midst of the global financial crisis.
#
# On that day, the stock market as a whole experienced a significant decline, with the Dow Jones Industrial Average (DJIA) falling by 332.13 points or about 4%. Bank stocks were particularly hard hit, as investors were concerned about the impact of the financial crisis on the banking sector. **

# %%
returns.idxmax()  #BEST DAY RETURNS
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** JPM best day return happened on January 21st 2009, the next day. This could lead to an analysis of the reason behind this sudden bounce, or the fact that the management did something quickly to make the market react as such the next day. The stock shows high volatility and risky agents might be more interested in investing while if you are a risk averse agent, you would want to sell your shares. The bounce back is very rare in financial history and it can all lead back to bank's internal control over the situation.**

# %% [markdown]
# # Evaluating the Stocks Volatility

# %% [markdown]
# ** Taking a look at the standard deviation of the returns, we can classify how risky the stock has been over the years. High standard deviation shows that the stock market had been much more shaky, rather than a smaller standard deviation proves that the stock has been more stable  **

# %%
returns.std() #over the years and C return is
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std() #For 2015
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Citigroup's stock is the shakiest followed by Morgan Stanley and Bank of America. And during 2015, only Morgan Stanley and Bank of America have higher stds but not by much. This shows a much more closer range between all banks in that time period. But based on this anlaysis, Morgan Stanley seem to have the most volatile stock overall. **

# %% [markdown]
# ** Distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='green', bins=50)

# %%
sns.displot(returns['C Return'],color='green', bins=100)

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import plotly.graph_objs as go
import plotly.offline as pyo
import plotly.express as px

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
cross_section = bank_stocks.xs(key='Close', axis=1, level='Stock Info')
fig = px.line(cross_section, color= 'Bank Ticker', title="My Scatter Plot")

# Display the plot
fig.show()
# Out:
# <div>                            <div id="63aaf221-bdb3-4b6a-8c82-ba0312592973" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63aaf221-bdb3-4b6a-8c82-ba0312592973")) {                    Plotly.newPlot(                        "63aaf221-bdb3-4b6a-8c82-ba0312592973",                        [{"hovertemplate":"Bank Ticker=BAC<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BAC","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BAC","showlegend":true,"x":["2006-01-03T00:00:00","2006-01-04T00:00:00","2006-01-05T00:00:00","2006-01-06T00:00:00","2006-01-09T00:00:00","2006-01-10T00:00:00","2006-01-11T00:00:00","2006-01-12T00:00:00","2006-01-13T00:00:00","2006-01-17T00:00:00","2006-01-18T00:00:00","2006-
# ...

# %%
fig = px.line(newdf, title="My Scatter Plot")
# Display the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/59/1yyxp0h910ngl7l951xhh5nm0000gn/T/ipykernel_50893/734159858.py in <module>
# ----> 1 fig = px.line(newdf, title="My Scatter Plot")
#       2 # Display the plot
#       3 fig.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     262     a polyline mark in 2D space.
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** The 30 day moving average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label= '30 Day Average')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %% [markdown]
# **A heatmap of the correlation between the stocks Close Price.**

# %%
cross_section = bank_stocks.xs(key='Close', axis=1, level='Stock Info')


sns.heatmap(cross_section.corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** We can also see a clustermap to cluster the correlations together**

# %%
sns.clustermap(cross_section.corr(),annot=True)

# %% [markdown]
# ** Looks like Citigroup, Bank of America and Morgan Stanley are grouped together correlation wise while the other three banks have a more similar correlation graph to each other as well. **
